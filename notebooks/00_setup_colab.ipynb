# %% [markdown]
# # Setup Colab - PFI MVP RM Lumbar
#
# Este notebook clona o actualiza el repositorio `PFI_MVPTest_Enzo` y prepara el entorno de ejecución en Google Colab.
#
# La fuente principal del código es GitHub. Colab se usa para ejecutar, entrenar y visualizar resultados con datos almacenados en Drive.
#
# **Importante:** este prototipo no emite diagnósticos, no recomienda tratamientos y no reemplaza el criterio profesional.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

REPO_URL = 'https://github.com/EnzoAA004/PFI_MVPTest_Enzo.git'
REPO_DIR = '/content/PFI_MVPTest_Enzo'

if not os.path.exists(REPO_DIR):
    # %cd /content
    # !git clone {REPO_URL}
else:
    # %cd {REPO_DIR}
    # !git pull origin main

# %cd {REPO_DIR}
# !pip install -e .

# %%
from lumbar_mri.config import get_project_paths, CLASSES

paths = get_project_paths()
print(paths)
print(CLASSES)

# %%
# !pytest -q

# %% [markdown]
# ## Próximo uso
#
# Cada vez que Codex o PyCharm suban cambios a GitHub, volver a ejecutar la celda de actualización del repositorio.
#
# Si se modifican módulos Python y Colab mantiene imports viejos, reiniciar el runtime y ejecutar nuevamente este setup.
