# %% [markdown]
# # 16_E8 FIXED - Al-Kafri mask decode and GT source comparison
#
# Este notebook continúa el rescate de Al-Kafri después de reconstruir el pairing oficial con `Slices Numbers.csv` leído con `header=None`.
#
# Objetivo: mejorar la visualización/decodificación de máscaras comparando fuentes de ground truth y estrategias de decodificación.
#
# No entrena modelos. Genera figuras diagnósticas y CSVs para decidir si se puede crear un subset axial entrenable.

# %%
import importlib.util, subprocess, sys

def ensure_package(import_name, pip_name=None):
    if importlib.util.find_spec(import_name) is None:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', pip_name or import_name])

ensure_package('pydicom')
ensure_package('skimage', 'scikit-image')

import ast, json, re, warnings
from pathlib import Path
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pydicom
from PIL import Image
from scipy import ndimage
from skimage.filters import threshold_multiotsu
from skimage.morphology import remove_small_objects, binary_closing, disk
from skimage.transform import resize
from tqdm.auto import tqdm

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 160)
pd.set_option('display.max_colwidth', 180)

try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=False)
except Exception as exc:
    print('Drive no montado automáticamente:', repr(exc))
# Out:
# Mounted at /content/drive

# %%
PFI_ROOT = Path('/content/drive/MyDrive/PFI_MVP')
ALKAFRI_ROOT = PFI_ROOT / 'data' / 'AXIAL_ALKAFRI'
EXTRACTED_ROOT = ALKAFRI_ROOT / 'extracted'
NESTED_ROOT = EXTRACTED_ROOT / '_nested'
E7_ROOT = PFI_ROOT / 'results' / 'E7_alkafri_axial_curated_subset'
E8_ROOT = PFI_ROOT / 'results' / 'E8_alkafri_official_pairing'
FIGURES_ROOT = PFI_ROOT / 'figures'
DOCS_ROOT = PFI_ROOT / 'docs'

for p in [E8_ROOT, FIGURES_ROOT, DOCS_ROOT]:
    p.mkdir(parents=True, exist_ok=True)

OFFICIAL_FILTERED_PATH = E8_ROOT / 'E8_official_pairing_candidates_HEADER_NONE_FILTERED.csv'
GT_INDEX_PATH = E7_ROOT / 'E7_alkafri_gt_case_index.csv'

print('PFI_ROOT:', PFI_ROOT)
print('OFFICIAL_FILTERED_PATH:', OFFICIAL_FILTERED_PATH, '| exists:', OFFICIAL_FILTERED_PATH.exists())
print('GT_INDEX_PATH:', GT_INDEX_PATH, '| exists:', GT_INDEX_PATH.exists())

if not OFFICIAL_FILTERED_PATH.exists():
    raise FileNotFoundError('Falta E8_official_pairing_candidates_HEADER_NONE_FILTERED.csv. Ejecutar primero el patch de pairing oficial HEADER_NONE.')
if not GT_INDEX_PATH.exists():
    raise FileNotFoundError('Falta E7_alkafri_gt_case_index.csv. Ejecutar primero notebooks E7/E8 base.')
# Out:
# PFI_ROOT: /content/drive/MyDrive/PFI_MVP
# OFFICIAL_FILTERED_PATH: /content/drive/MyDrive/PFI_MVP/results/E8_alkafri_official_pairing/E8_official_pairing_candidates_HEADER_NONE_FILTERED.csv | exists: True
# GT_INDEX_PATH: /content/drive/MyDrive/PFI_MVP/results/E7_alkafri_axial_curated_subset/E7_alkafri_gt_case_index.csv | exists: True

# %%
def norm_case(x):
    if pd.isna(x):
        return None
    m = re.search(r'(\d{1,4})', str(x))
    return f'{int(m.group(1)):04d}' if m else None

def infer_gt_type(path):
    s = str(path).lower()
    if '05_final' in s or 'final_ground_truth' in s:
        return 'final'
    if '04_intermediary' in s or 'intermediary' in s:
        return 'intermediary'
    if '03_manual' in s or 'manual_label' in s or 'labeller' in s:
        return 'manual'
    return 'unknown'

def parse_gt_filename(path):
    name = Path(path).name
    m = re.search(r'(T[12])[_-](\d{1,4})[_-]D([345])', name, re.I)
    if not m:
        return None, None, None
    return m.group(1).upper(), f'{int(m.group(2)):04d}', int(m.group(3))

def read_dicom(path):
    ds = pydicom.dcmread(str(path), force=True)
    _ = ds.pixel_array
    return ds

def normalize_image(arr):
    arr = arr.astype(np.float32)
    p1, p99 = np.percentile(arr, [1, 99])
    if p99 <= p1:
        return np.zeros_like(arr, dtype=np.float32)
    return (np.clip(arr, p1, p99) - p1) / (p99 - p1 + 1e-8)

def read_mask_raw(path):
    with Image.open(path) as img:
        arr = np.asarray(img)
    if arr.ndim == 3 and arr.shape[-1] == 4:
        arr = arr[..., :3]
    return arr

def to_gray_for_decode(arr):
    if arr.ndim == 2:
        return arr.astype(np.float32)
    return arr[..., :3].astype(np.float32).mean(axis=-1)

def border_values(arr):
    a = to_gray_for_decode(arr)
    return np.concatenate([a[0, :], a[-1, :], a[:, 0], a[:, -1]])

def dominant_scalar(values):
    vals = np.asarray(values).reshape(-1)
    if vals.size == 0:
        return None
    vals_i = np.round(vals).astype(np.int32)
    c = Counter(vals_i.tolist())
    return c.most_common(1)[0][0]

def clean_binary(mask, min_size=80, close_radius=1):
    mask = mask.astype(bool)
    if close_radius and mask.any():
        mask = binary_closing(mask, disk(close_radius))
    if mask.any():
        mask = remove_small_objects(mask, min_size=min_size)
    return mask.astype(np.uint8)

def component_count(mask):
    _, n = ndimage.label(mask.astype(bool))
    return int(n)

def resize_mask_if_needed(mask, target_shape):
    if tuple(mask.shape) == tuple(target_shape):
        return mask.astype(np.uint8)
    return (resize(mask.astype(np.float32), target_shape, order=0, preserve_range=True, anti_aliasing=False) > 0.5).astype(np.uint8)

def unique_profile(arr, max_items=15):
    if arr.ndim == 3:
        flat = arr.reshape(-1, arr.shape[-1])
        vals, counts = np.unique(flat, axis=0, return_counts=True)
        values = [tuple(map(int, v.tolist())) for v in vals]
    else:
        vals, counts = np.unique(arr.reshape(-1), return_counts=True)
        values = [int(v) for v in vals]
    order = np.argsort(counts)[::-1]
    total = int(np.prod(arr.shape[:2]))
    rows = []
    for idx in order[:max_items]:
        rows.append({'value': str(values[idx]), 'count': int(counts[idx]), 'ratio': float(counts[idx] / total)})
    return rows, len(vals)

# %%
# 1) Cargar candidatos oficiales filtrados y reconstruir pool de GT por fuente
official_df = pd.read_csv(OFFICIAL_FILTERED_PATH)
official_df['case_id_norm'] = official_df['case_id'].apply(norm_case)
official_df['disc_id'] = pd.to_numeric(official_df['disc_id'], errors='coerce').astype('Int64')
official_df['slice_offset'] = pd.to_numeric(official_df['slice_offset'], errors='coerce')

gt_df = pd.read_csv(GT_INDEX_PATH, low_memory=False)
gt_df = gt_df[gt_df['extension'].astype(str).str.lower().eq('.png')].copy()
gt_df['gt_type_fixed'] = gt_df['gt_file_path'].apply(infer_gt_type)
parsed = gt_df['gt_file_path'].apply(parse_gt_filename)
gt_df['modality_from_name'] = parsed.apply(lambda x: x[0])
gt_df['case_id_norm_from_name'] = parsed.apply(lambda x: x[1])
gt_df['disc_id_from_name'] = parsed.apply(lambda x: x[2])
gt_df['case_id_norm'] = gt_df['case_id_norm_from_name'].fillna(gt_df['case_id'].apply(norm_case))
gt_df['modality'] = gt_df['modality_from_name'].fillna(gt_df.get('modality'))
gt_df['disc_id'] = pd.to_numeric(gt_df['disc_id_from_name'].fillna(gt_df.get('disc_or_slice_id')), errors='coerce').astype('Int64')
gt_df['gt_type'] = gt_df['gt_type_fixed'].where(gt_df['gt_type_fixed'].ne('unknown'), gt_df.get('gt_type'))

gt_df = gt_df[gt_df['case_id_norm'].notna() & gt_df['modality'].notna() & gt_df['disc_id'].notna()].copy()
gt_df['gt_priority'] = gt_df['gt_type'].map({'final': 0, 'intermediary': 1, 'manual': 2}).fillna(9).astype(int)

print('official_df:', official_df.shape)
print('gt_df png parsed:', gt_df.shape)
display(gt_df.groupby(['gt_type', 'modality'], dropna=False).size().reset_index(name='n').sort_values(['gt_type', 'modality']))

# Crear una tabla comparativa de fuentes disponibles por caso/modalidad/disco
gt_source_summary = (
    gt_df.groupby(['case_id_norm', 'modality', 'disc_id', 'gt_type'], dropna=False)
    .agg(n_files=('gt_file_path', 'count'), first_path=('gt_file_path', 'first'))
    .reset_index()
)
gt_source_summary.to_csv(E8_ROOT / 'E8_FIXED_gt_sources_by_case_modality_disc.csv', index=False)
display(gt_source_summary.head(30))

# Seleccionar mejor GT disponible para cada candidato oficial: final > intermediary > manual
base_cols = [c for c in official_df.columns if c not in ['gt_file_path', 'gt_type']]
merged = official_df[base_cols].merge(
    gt_df[['case_id_norm', 'modality', 'disc_id', 'gt_file_path', 'gt_type', 'gt_priority']],
    on=['case_id_norm', 'modality', 'disc_id'],
    how='left'
)
merged = merged.sort_values(['case_id_norm', 'modality', 'disc_id', 'image_file_path', 'gt_priority', 'gt_file_path'])
selected_df = merged.drop_duplicates(subset=['case_id_norm', 'modality', 'disc_id', 'image_file_path'], keep='first').copy()
selected_df = selected_df[selected_df['gt_file_path'].notna()].copy()

selected_df.to_csv(E8_ROOT / 'E8_FIXED_official_candidates_best_gt_source.csv', index=False)
print('selected_df:', selected_df.shape)
display(selected_df.groupby(['gt_type', 'modality'], dropna=False).size().reset_index(name='n').sort_values(['gt_type', 'modality']))
display(selected_df.head(20))
# Out:
# official_df: (1201, 14)
# gt_df png parsed: (18540, 15)
#         gt_type modality      n
# 0  intermediary       T1   1545
# 1  intermediary       T2   1545
# 2        manual       T1  15450
#    case_id_norm modality  disc_id       gt_type  n_files  \
# 0          0001       T1        3  intermediary        1
# 1          0001       T1        3        manual       10
# 2          0001       T1        4  intermediary        1
# 3          0001       T1        4        manual       10
# 4          0001       T1        5  intermediary        1
# 5          0001       T1        5        manual       10
# 6          0001       T2        3  intermediary        1
# 7          0001       T2        4  intermediary        1
# 8          0001       T2        5  intermediary        1
# 9          0002       T1        3  intermediary        1
# 10         0002       T1        3        manual       10
# 11         0002       T1        4  intermediary        1
# 12         0002       T1        4        manual       10
# 13         0002       T1        5  intermediary        1
# 14         0002       T1        5        manual       10
# 15         0002       T2        3  intermediary        1
# 16         0002       T2        4  intermediary        1
# 17         0002       T2        5  intermediary        1
# 18         0003       T1        3  intermediary        1
# 19         0003       T1        3        manual       10
# 20         0003       T1        4  intermediary        1
# 21         0003       T1        4        manual       10
# 22         0003       T1        5  intermediary        1
# 23         0003       T1        5        manual       10
# 24         0003       T2        3  intermediary        1
# 25         0003       T2        4  intermediary        1
# 26         0003       T2        5  intermediary        1
# 27         0004       T1        3  intermediary        1
# 28         0004       T1        3        manual       10
# 29         0004       T1        4  intermediary        1
#
#                                                                                                                                                          first_path
# 0   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0001_D3.png
# 1               /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Manual_Label_Data/03_Manual_Label_Data/Labeller 01/T1_0001_D3.png
# 2   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0001_D4.png
# 3               /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Manual_Label_Data/03_Manual_Label_Data/Labeller 01/T1_0001_D4.png
# 4   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0001_D5.png
# 5               /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Manual_Label_Data/03_Manual_Label_Data/Labeller 01/T1_0001_D5.png
# 6   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0001_D3.png
# 7   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0001_D4.png
# 8   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0001_D5.png
# 9   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0002_D3.png
# 10              /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Manual_Label_Data/03_Manual_Label_Data/Labeller 01/T1_0002_D3.png
# 11  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0002_D4.png
# 12              /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Manual_Label_Data/03_Manual_Label_Data/Labeller 01/T1_0002_D4.png
# 13  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0002_D5.png
# 14              /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Manual_Label_Data/03_Manual_Label_Data/Labeller 01/T1_0002_D5.png
# 15  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0002_D3.png
# 16  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0002_D4.png
# 17  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0002_D5.png
# 18  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0003_D3.png
# 19              /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Manual_Label_Data/03_Manual_Label_Data/Labeller 01/T1_0003_D3.png
# 20  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0003_D4.png
# 21              /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Manual_Label_Data/03_Manual_Label_Data/Labeller 01/T1_0003_D4.png
# 22  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0003_D5.png
# 23              /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Manual_Label_Data/03_Manual_Label_Data/Labeller 01/T1_0003_D5.png
# 24  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0003_D3.png
# 25  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0003_D4.png
# 26  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0003_D5.png
# 27  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0004_D3.png
# 28              /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Manual_Label_Data/03_Manual_Label_Data/Labeller 01/T1_0004_D3.png
# 29  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0004_D4.png
# selected_df: (1201, 15)
#         gt_type modality    n
# 0  intermediary       T1  591
# 1  intermediary       T2  610
#                               strategy  case_id modality  disc_id  \
# 10   official_slice_number_header_none        1       T1        3
# 21   official_slice_number_header_none        1       T1        4
# 32   official_slice_number_header_none        1       T1        5
# 33   official_slice_number_header_none        1       T2        3
# 34   official_slice_number_header_none        1       T2        4
# 35   official_slice_number_header_none        1       T2        5
# 46   official_slice_number_header_none        2       T1        3
# 57   official_slice_number_header_none        2       T1        4
# 68   official_slice_number_header_none        2       T1        5
# 69   official_slice_number_header_none        2       T2        3
# 70   official_slice_number_header_none        2       T2        4
# 71   official_slice_number_header_none        2       T2        5
# 82   official_slice_number_header_none        3       T1        3
# 93   official_slice_number_header_none        3       T1        4
# 104  official_slice_number_header_none        3       T1        5
# 105  official_slice_number_header_none        3       T2        3
# 106  official_slice_number_header_none        3       T2        4
# 107  official_slice_number_header_none        3       T2        5
# 118  official_slice_number_header_none        4       T1        3
# 129  official_slice_number_header_none        4       T1        4
#
#      slice_number  slice_offset  instance_number   subfolder  \
# 10              3             0                3  T1_TSE_TRA
# 21              7             0                7  T1_TSE_TRA
# 32             11             0               11  T1_TSE_TRA
# 33              3             0                3  T2_TSE_TRA
# 34              7             0                7  T2_TSE_TRA
# 35             11             0               11  T2_TSE_TRA
# 46              3             0                3  T1_TSE_TRA
# 57              8             0                8  T1_TSE_TRA
# 68             13             0               13  T1_TSE_TRA
# 69              3             0                3  T2_TSE_TRA
# 70              8             0                8  T2_TSE_TRA
# 71             13             0               13  T2_TSE_TRA
# 82              3             0                3  T1_TSE_TRA
# 93              8             0                8  T1_TSE_TRA
# 104            13             0               13  T1_TSE_TRA
# 105             3             0                3  T2_TSE_TRA
# 106             8             0                8  T2_TSE_TRA
# 107            13             0               13  T2_TSE_TRA
# 118             3             0                3  T1_TSE_TRA
# 129             8             0                8  T1_TSE_TRA
#
#     series_description  \
# 10          t1_tse_tra
# 21          t1_tse_tra
# 32          t1_tse_tra
# 33      t2_tse_tra_384
# 34      t2_tse_tra_384
# 35      t2_tse_tra_384
# 46          t1_tse_tra
# 57          t1_tse_tra
# 68          t1_tse_tra
# 69      t2_tse_tra_384
# 70      t2_tse_tra_384
# 71      t2_tse_tra_384
# 82          t1_tse_tra
# 93          t1_tse_tra
# 104         t1_tse_tra
# 105     t2_tse_tra_384
# 106     t2_tse_tra_384
# 107     t2_tse_tra_384
# 118         t1_tse_tra
# 129         t1_tse_tra
#
#                                                                                                                                                                          image_file_path  \
# 10   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T1_TSE_TRA_0005/T1_TSE_TRA__0001_...
# 21   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T1_TSE_TRA_0005/T1_TSE_TRA__0001_...
# 32   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T1_TSE_TRA_0005/T1_TSE_TRA__0001_...
# 33   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 34   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 35   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 46   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T1_TSE_TRA_0005/T1...
# 57   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T1_TSE_TRA_0005/T1...
# 68   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T1_TSE_TRA_0005/T1...
# 69   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T2_TSE_TRA_384_000...
# 70   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T2_TSE_TRA_384_000...
# 71   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T2_TSE_TRA_384_000...
# 82   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T1_TSE_TRA_0005/T1_TSE_TRA__0003_...
# 93   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T1_TSE_TRA_0005/T1_TSE_TRA__0003_...
# 104  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T1_TSE_TRA_0005/T1_TSE_TRA__0003_...
# 105  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 106  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 107  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 118  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0004/L-SPINE_CLINICAL_LIBRARIES_20160526_115018_014000/T1_TSE_TRA_0005/T1...
# 129  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0004/L-SPINE_CLINICAL_LIBRARIES_20160526_115018_014000/T1_TSE_TRA_0005/T1...
#
#                                                                                 evidence  \
# 10   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 21   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 32   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 33   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 34   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 35   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 46   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 57   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 68   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 69   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 70   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 71   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 82   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 93   official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 104  official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 105  official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 106  official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 107  official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 118  official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
# 129  official Slices Numbers.csv + T1/T2_Subfolders.csv + case/modality/disc/slice match
#
#     case_id_norm  \
# 10          0001
# 21          0001
# 32          0001
# 33          0001
# 34          0001
# 35          0001
# 46          0002
# 57          0002
# 68          0002
# 69          0002
# 70          0002
# 71          0002
# 82          0003
# 93          0003
# 104         0003
# 105         0003
# 106         0003
# 107         0003
# 118         0004
# 129         0004
#
#                                                                                                                                                         gt_file_path  \
# 10   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0001_D3.png
# 21   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0001_D4.png
# 32   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0001_D5.png
# 33   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0001_D3.png
# 34   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0001_D4.png
# 35   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0001_D5.png
# 46   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0002_D3.png
# 57   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0002_D4.png
# 68   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0002_D5.png
# 69   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0002_D3.png
# 70   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0002_D4.png
# 71   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0002_D5.png
# 82   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0003_D3.png
# 93   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0003_D4.png
# 104  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0003_D5.png
# 105  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0003_D3.png
# 106  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0003_D4.png
# 107  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0003_D5.png
# 118  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0004_D3.png
# 129  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0004_D4.png
#
#           gt_type  gt_priority
# 10   intermediary            1
# 21   intermediary            1
# 32   intermediary            1
# 33   intermediary            1
# 34   intermediary            1
# 35   intermediary            1
# 46   intermediary            1
# 57   intermediary            1
# 68   intermediary            1
# 69   intermediary            1
# 70   intermediary            1
# 71   intermediary            1
# 82   intermediary            1
# 93   intermediary            1
# 104  intermediary            1
# 105  intermediary            1
# 106  intermediary            1
# 107  intermediary            1
# 118  intermediary            1
# 129  intermediary            1

# %%
# 2) Estrategias de decodificación mejoradas

def decode_exact_label_like(raw, min_ratio=0.0005, max_ratio=0.40, min_size=80):
    # Sirve cuando la máscara es realmente label map discreto.
    gray = to_gray_for_decode(raw)
    gi = np.round(gray).astype(np.int32)
    vals, counts = np.unique(gi.reshape(-1), return_counts=True)
    total = gi.size
    border_bg = dominant_scalar(border_values(gi))
    mask = np.zeros_like(gi, dtype=bool)
    used = []
    for v, c in zip(vals, counts):
        ratio = c / total
        if int(v) == int(border_bg):
            continue
        if min_ratio <= ratio <= max_ratio:
            mask |= (gi == v)
            used.append(int(v))
    return clean_binary(mask, min_size=min_size, close_radius=1), {'method': 'exact_label_like', 'used_values': used, 'unique_count': int(len(vals)), 'border_bg': int(border_bg)}

def decode_range_clean(raw, top_k=8, tolerance=2, min_ratio=0.004, max_ratio=0.18, min_size=120):
    # Agrupa valores cercanos para evitar speckles por variaciones pequeñas de intensidad.
    gray = to_gray_for_decode(raw)
    gi = np.round(gray).astype(np.int32)
    vals, counts = np.unique(gi.reshape(-1), return_counts=True)
    total = gi.size
    border_bg = dominant_scalar(border_values(gi))
    order = np.argsort(counts)[::-1]
    mask = np.zeros_like(gi, dtype=bool)
    used = []
    for idx in order:
        v = int(vals[idx])
        ratio = counts[idx] / total
        if v == border_bg:
            continue
        if min_ratio <= ratio <= max_ratio:
            mask |= np.abs(gi - v) <= tolerance
            used.append(v)
        if len(used) >= top_k:
            break
    return clean_binary(mask, min_size=min_size, close_radius=2), {'method': 'range_clean_pm2', 'used_values': used, 'unique_count': int(len(vals)), 'border_bg': int(border_bg)}

def decode_multiotsu_non_border(raw, classes=5, min_size=200):
    # Para GT intermedio tipo mapa continuo: segmenta en bandas y excluye clase dominante del borde.
    gray = to_gray_for_decode(raw)
    if np.nanmax(gray) <= np.nanmin(gray):
        return np.zeros_like(gray, dtype=np.uint8), {'method': 'multiotsu_non_border', 'classes': 0, 'border_class': None}
    # multiotsu falla si hay muy pocos niveles; se reduce classes si hace falta.
    unique_count = len(np.unique(np.round(gray).astype(np.int32)))
    c = min(classes, max(2, unique_count))
    try:
        th = threshold_multiotsu(gray, classes=c)
        regions = np.digitize(gray, th)
    except Exception:
        q = np.percentile(gray, [20, 40, 60, 80])
        regions = np.digitize(gray, q)
        th = q
    border_class = dominant_scalar(border_values(regions))
    mask = regions != border_class
    mask = clean_binary(mask, min_size=min_size, close_radius=2)
    return mask, {'method': 'multiotsu_non_border', 'thresholds': [float(x) for x in np.asarray(th).reshape(-1)], 'border_class': int(border_class), 'unique_count': int(unique_count)}

def select_best_decode(raw):
    # Genera varias versiones. La selección automática es solo diagnóstica; la decisión final es visual.
    raw_profile, unique_count = unique_profile(raw, max_items=12)
    exact, info_exact = decode_exact_label_like(raw)
    range_m, info_range = decode_range_clean(raw)
    otsu_m, info_otsu = decode_multiotsu_non_border(raw)

    candidates = [
        ('exact_label_like', exact, info_exact),
        ('range_clean_pm2', range_m, info_range),
        ('multiotsu_non_border', otsu_m, info_otsu),
    ]

    scored = []
    for name, m, info in candidates:
        ratio = float(m.mean())
        comps = component_count(m)
        # Penaliza máscaras vacías, enormes o con demasiados componentes.
        score = 0
        if 0.005 <= ratio <= 0.45:
            score += 2
        if comps <= 80:
            score += 2
        elif comps <= 250:
            score += 1
        if ratio < 0.002 or ratio > 0.65:
            score -= 3
        scored.append((score, name, m, {**info, 'foreground_ratio': ratio, 'components': comps, 'raw_profile': raw_profile}))

    scored = sorted(scored, key=lambda x: x[0], reverse=True)
    return scored[0][2], {'selected_method': scored[0][1], 'score': int(scored[0][0]), **scored[0][3]}, {name: (m, info) for _, name, m, info in scored}

print('Funciones de decode listas.')
# Out:
# Funciones de decode listas.

# %%
# 3) Generar figuras FIXED comparando raw GT y 3 decodificaciones

VIS_N = 120

vis_df = (
    selected_df
    .sort_values(['case_id_norm', 'modality', 'disc_id', 'instance_number'])
    .groupby(['modality', 'disc_id'], group_keys=False)
    .head(25)
    .head(VIS_N)
    .copy()
)

print('Candidatos FIXED a visualizar:', len(vis_df))
review_rows = []

for i, (_, r) in enumerate(tqdm(vis_df.iterrows(), total=len(vis_df), desc='fixed mask decode'), start=1):
    cid = f'fixed_mask_decode_{i:03d}'
    try:
        ds = read_dicom(r['image_file_path'])
        img = ds.pixel_array.astype(np.float32)
        img_norm = normalize_image(img)
        raw = read_mask_raw(r['gt_file_path'])

        best_mask, best_info, all_decodes = select_best_decode(raw)
        best_mask = resize_mask_if_needed(best_mask, img.shape)

        exact_m, exact_i = all_decodes.get('exact_label_like')
        range_m, range_i = all_decodes.get('range_clean_pm2')
        otsu_m, otsu_i = all_decodes.get('multiotsu_non_border')
        exact_m = resize_mask_if_needed(exact_m, img.shape)
        range_m = resize_mask_if_needed(range_m, img.shape)
        otsu_m = resize_mask_if_needed(otsu_m, img.shape)

        raw_profile, unique_count = unique_profile(raw, max_items=10)

        fig, axes = plt.subplots(1, 6, figsize=(24, 4))
        axes[0].imshow(img_norm, cmap='gray')
        axes[0].set_title('Axial IMA')
        axes[0].axis('off')

        axes[1].imshow(raw if raw.ndim == 3 else raw, cmap=None if raw.ndim == 3 else 'nipy_spectral')
        axes[1].set_title(f'Raw GT\n{r["gt_type"]} | unique={unique_count}')
        axes[1].axis('off')

        for ax, m, title in [
            (axes[2], exact_m, f'exact label-like\nratio={exact_m.mean():.3f} comps={component_count(exact_m)}'),
            (axes[3], range_m, f'range clean ±2\nratio={range_m.mean():.3f} comps={component_count(range_m)}'),
            (axes[4], otsu_m, f'multiotsu non-border\nratio={otsu_m.mean():.3f} comps={component_count(otsu_m)}'),
            (axes[5], best_mask, f'BEST: {best_info["selected_method"]}\nratio={best_mask.mean():.3f} comps={component_count(best_mask)}'),
        ]:
            ax.imshow(img_norm, cmap='gray')
            ax.imshow(np.ma.masked_where(m <= 0, m), alpha=0.45, cmap='autumn')
            ax.set_title(title)
            ax.axis('off')

        fig.suptitle(
            f'{cid} | official HEADER_NONE | case={r["case_id_norm"]} | {r["modality"]} | D={r["disc_id"]} | '
            f'slice={r.get("slice_number", "?")} | inst={r.get("instance_number", "?")} | gt={r["gt_type"]}',
            fontsize=10
        )
        fig.tight_layout()
        fig_path = FIGURES_ROOT / f'E8_alkafri_FIXED_MASK_DECODE_{i:03d}.png'
        fig.savefig(fig_path, dpi=150, bbox_inches='tight')
        plt.close(fig)

        review_rows.append({
            'candidate_id': cid,
            'figure_path': str(fig_path),
            'strategy': r.get('strategy'),
            'case_id': r['case_id_norm'],
            'modality': r['modality'],
            'disc_id': int(r['disc_id']),
            'slice_number': r.get('slice_number'),
            'instance_number': r.get('instance_number'),
            'gt_type': r['gt_type'],
            'gt_file_path': r['gt_file_path'],
            'image_file_path': r['image_file_path'],
            'raw_unique_count': int(unique_count),
            'raw_profile': json.dumps(raw_profile, ensure_ascii=False),
            'selected_decode_method': best_info['selected_method'],
            'selected_foreground_ratio': float(best_mask.mean()),
            'selected_component_count': component_count(best_mask),
            'decode_info': json.dumps(best_info, ensure_ascii=False),
            'auto_status': 'review',
            'manual_accept': '',
            'manual_reject_reason': '',
            'notes': '',
        })

    except Exception as exc:
        review_rows.append({
            'candidate_id': cid,
            'auto_status': 'error',
            'error': repr(exc),
            'case_id': r.get('case_id_norm'),
            'modality': r.get('modality'),
            'disc_id': r.get('disc_id'),
            'gt_file_path': r.get('gt_file_path'),
            'image_file_path': r.get('image_file_path'),
        })

review_fixed_df = pd.DataFrame(review_rows)
review_fixed_path = E8_ROOT / 'E8_FIXED_mask_decode_visual_review_sheet.csv'
review_fixed_df.to_csv(review_fixed_path, index=False)

print('Figuras FIXED generadas:', int(review_fixed_df.get('figure_path', pd.Series(dtype=object)).notna().sum()))
print('Review sheet:', review_fixed_path)
display(review_fixed_df.head(30))
display(review_fixed_df.groupby(['gt_type', 'modality', 'selected_decode_method'], dropna=False).size().reset_index(name='n').sort_values('n', ascending=False))
# Out:
# Candidatos FIXED a visualizar: 120
# fixed mask decode:   0%|          | 0/120 [00:00<?, ?it/s]
# Figuras FIXED generadas: 120
# Review sheet: /content/drive/MyDrive/PFI_MVP/results/E8_alkafri_official_pairing/E8_FIXED_mask_decode_visual_review_sheet.csv
#              candidate_id  \
# 0   fixed_mask_decode_001
# 1   fixed_mask_decode_002
# 2   fixed_mask_decode_003
# 3   fixed_mask_decode_004
# 4   fixed_mask_decode_005
# 5   fixed_mask_decode_006
# 6   fixed_mask_decode_007
# 7   fixed_mask_decode_008
# 8   fixed_mask_decode_009
# 9   fixed_mask_decode_010
# 10  fixed_mask_decode_011
# 11  fixed_mask_decode_012
# 12  fixed_mask_decode_013
# 13  fixed_mask_decode_014
# 14  fixed_mask_decode_015
# 15  fixed_mask_decode_016
# 16  fixed_mask_decode_017
# 17  fixed_mask_decode_018
# 18  fixed_mask_decode_019
# 19  fixed_mask_decode_020
# 20  fixed_mask_decode_021
# 21  fixed_mask_decode_022
# 22  fixed_mask_decode_023
# 23  fixed_mask_decode_024
# 24  fixed_mask_decode_025
# 25  fixed_mask_decode_026
# 26  fixed_mask_decode_027
# 27  fixed_mask_decode_028
# 28  fixed_mask_decode_029
# 29  fixed_mask_decode_030
#
#                                                                     figure_path  \
# 0   /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_001.png
# 1   /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_002.png
# 2   /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_003.png
# 3   /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_004.png
# 4   /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_005.png
# 5   /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_006.png
# 6   /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_007.png
# 7   /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_008.png
# 8   /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_009.png
# 9   /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_010.png
# 10  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_011.png
# 11  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_012.png
# 12  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_013.png
# 13  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_014.png
# 14  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_015.png
# 15  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_016.png
# 16  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_017.png
# 17  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_018.png
# 18  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_019.png
# 19  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_020.png
# 20  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_021.png
# 21  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_022.png
# 22  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_023.png
# 23  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_024.png
# 24  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_025.png
# 25  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_026.png
# 26  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_027.png
# 27  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_028.png
# 28  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_029.png
# 29  /content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_030.png
#
#                              strategy case_id modality  disc_id  slice_number  \
# 0   official_slice_number_header_none    0001       T1        3             3
# 1   official_slice_number_header_none    0001       T1        4             7
# 2   official_slice_number_header_none    0001       T1        5            11
# 3   official_slice_number_header_none    0001       T2        3             3
# 4   official_slice_number_header_none    0001       T2        4             7
# 5   official_slice_number_header_none    0001       T2        5            11
# 6   official_slice_number_header_none    0002       T1        3             3
# 7   official_slice_number_header_none    0002       T1        4             8
# 8   official_slice_number_header_none    0002       T1        5            13
# 9   official_slice_number_header_none    0002       T2        3             3
# 10  official_slice_number_header_none    0002       T2        4             8
# 11  official_slice_number_header_none    0002       T2        5            13
# 12  official_slice_number_header_none    0003       T1        3             3
# 13  official_slice_number_header_none    0003       T1        4             8
# 14  official_slice_number_header_none    0003       T1        5            13
# 15  official_slice_number_header_none    0003       T2        3             3
# 16  official_slice_number_header_none    0003       T2        4             8
# 17  official_slice_number_header_none    0003       T2        5            13
# 18  official_slice_number_header_none    0004       T1        3             3
# 19  official_slice_number_header_none    0004       T1        4             8
# 20  official_slice_number_header_none    0004       T1        5            13
# 21  official_slice_number_header_none    0004       T2        3             3
# 22  official_slice_number_header_none    0004       T2        4             8
# 23  official_slice_number_header_none    0004       T2        5            13
# 24  official_slice_number_header_none    0005       T1        3             3
# 25  official_slice_number_header_none    0005       T1        4             8
# 26  official_slice_number_header_none    0005       T1        5            13
# 27  official_slice_number_header_none    0005       T2        3             3
# 28  official_slice_number_header_none    0005       T2        4             8
# 29  official_slice_number_header_none    0005       T2        5            13
#
#     instance_number       gt_type  \
# 0                 3  intermediary
# 1                 7  intermediary
# 2                11  intermediary
# 3                 3  intermediary
# 4                 7  intermediary
# 5                11  intermediary
# 6                 3  intermediary
# 7                 8  intermediary
# 8                13  intermediary
# 9                 3  intermediary
# 10                8  intermediary
# 11               13  intermediary
# 12                3  intermediary
# 13                8  intermediary
# 14               13  intermediary
# 15                3  intermediary
# 16                8  intermediary
# 17               13  intermediary
# 18                3  intermediary
# 19                8  intermediary
# 20               13  intermediary
# 21                3  intermediary
# 22                8  intermediary
# 23               13  intermediary
# 24                3  intermediary
# 25                8  intermediary
# 26               13  intermediary
# 27                3  intermediary
# 28                8  intermediary
# 29               13  intermediary
#
#                                                                                                                                                        gt_file_path  \
# 0   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0001_D3.png
# 1   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0001_D4.png
# 2   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0001_D5.png
# 3   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0001_D3.png
# 4   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0001_D4.png
# 5   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0001_D5.png
# 6   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0002_D3.png
# 7   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0002_D4.png
# 8   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0002_D5.png
# 9   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0002_D3.png
# 10  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0002_D4.png
# 11  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0002_D5.png
# 12  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0003_D3.png
# 13  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0003_D4.png
# 14  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0003_D5.png
# 15  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0003_D3.png
# 16  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0003_D4.png
# 17  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0003_D5.png
# 18  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0004_D3.png
# 19  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0004_D4.png
# 20  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0004_D5.png
# 21  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0004_D3.png
# 22  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0004_D4.png
# 23  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0004_D5.png
# 24  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0005_D3.png
# 25  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0005_D4.png
# 26  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T1_Output/T1_0005_D5.png
# 27  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0005_D3.png
# 28  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0005_D4.png
# 29  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/04_Intermediary_Ground_Truth_Data/T2_Output/T2_0005_D5.png
#
#                                                                                                                                                                         image_file_path  \
# 0   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T1_TSE_TRA_0005/T1_TSE_TRA__0001_...
# 1   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T1_TSE_TRA_0005/T1_TSE_TRA__0001_...
# 2   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T1_TSE_TRA_0005/T1_TSE_TRA__0001_...
# 3   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 4   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 5   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0001/L-SPINE_LSS_20160309_091629_240000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 6   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T1_TSE_TRA_0005/T1...
# 7   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T1_TSE_TRA_0005/T1...
# 8   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T1_TSE_TRA_0005/T1...
# 9   /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T2_TSE_TRA_384_000...
# 10  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T2_TSE_TRA_384_000...
# 11  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0002/L-SPINE_CLINICAL_LIBRARIES_20160621_112938_873000/T2_TSE_TRA_384_000...
# 12  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T1_TSE_TRA_0005/T1_TSE_TRA__0003_...
# 13  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T1_TSE_TRA_0005/T1_TSE_TRA__0003_...
# 14  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T1_TSE_TRA_0005/T1_TSE_TRA__0003_...
# 15  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 16  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 17  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0003/L-SPINE_LSS_20160411_134646_314000/T2_TSE_TRA_384_0004/T2_TSE_TRA__0...
# 18  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0004/L-SPINE_CLINICAL_LIBRARIES_20160526_115018_014000/T1_TSE_TRA_0005/T1...
# 19  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0004/L-SPINE_CLINICAL_LIBRARIES_20160526_115018_014000/T1_TSE_TRA_0005/T1...
# 20  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0004/L-SPINE_CLINICAL_LIBRARIES_20160526_115018_014000/T1_TSE_TRA_0005/T1...
# 21  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0004/L-SPINE_CLINICAL_LIBRARIES_20160526_115018_014000/T2_TSE_TRA_384_000...
# 22  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0004/L-SPINE_CLINICAL_LIBRARIES_20160526_115018_014000/T2_TSE_TRA_384_000...
# 23  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0004/L-SPINE_CLINICAL_LIBRARIES_20160526_115018_014000/T2_TSE_TRA_384_000...
# 24  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0005/L-SPINE_CLINICAL_LIBRARIES_20160608_132349_824000/T1_TSE_TRA_0005/T1...
# 25  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0005/L-SPINE_CLINICAL_LIBRARIES_20160608_132349_824000/T1_TSE_TRA_0005/T1...
# 26  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0005/L-SPINE_CLINICAL_LIBRARIES_20160608_132349_824000/T1_TSE_TRA_0005/T1...
# 27  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0005/L-SPINE_CLINICAL_LIBRARIES_20160608_132349_824000/T2_TSE_TRA_384_000...
# 28  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0005/L-SPINE_CLINICAL_LIBRARIES_20160608_132349_824000/T2_TSE_TRA_384_000...
# 29  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/main_dataset__MRI_Data/01_MRI_Data/0005/L-SPINE_CLINICAL_LIBRARIES_20160608_132349_824000/T2_TSE_TRA_384_000...
#
#     raw_unique_count  \
# 0                252
# 1                249
# 2                244
# 3                255
# 4                253
# 5                252
# 6                253
# 7                251
# 8                253
# 9                253
# 10               247
# 11               248
# 12               254
# 13               247
# 14               250
# 15               243
# 16               252
# 17               247
# 18               250
# 19               250
# 20               244
# 21               255
# 22               246
# 23               241
# 24               256
# 25               256
# 26               243
# 27               245
# 28               256
# 29               251
#
#                                                                                                                                                                             raw_profile  \
# 0   [{"value": "9", "count": 3896, "ratio": 0.038046875}, {"value": "8", "count": 3841, "ratio": 0.037509765625}, {"value": "10", "count": 3590, "ratio": 0.03505859375}, {"value": ...
# 1   [{"value": "8", "count": 5335, "ratio": 0.052099609375}, {"value": "5", "count": 4974, "ratio": 0.04857421875}, {"value": "6", "count": 4500, "ratio": 0.0439453125}, {"value": ...
# 2   [{"value": "4", "count": 4746, "ratio": 0.04634765625}, {"value": "5", "count": 4030, "ratio": 0.03935546875}, {"value": "6", "count": 3719, "ratio": 0.036318359375}, {"value":...
# 3   [{"value": "8", "count": 5487, "ratio": 0.053583984375}, {"value": "10", "count": 5419, "ratio": 0.052919921875}, {"value": "12", "count": 4599, "ratio": 0.044912109375}, {"val...
# 4   [{"value": "8", "count": 6133, "ratio": 0.059892578125}, {"value": "7", "count": 5903, "ratio": 0.057646484375}, {"value": "9", "count": 5661, "ratio": 0.055283203125}, {"value...
# 5   [{"value": "7", "count": 4951, "ratio": 0.048349609375}, {"value": "6", "count": 4773, "ratio": 0.046611328125}, {"value": "9", "count": 4135, "ratio": 0.040380859375}, {"value...
# 6   [{"value": "4", "count": 6837, "ratio": 0.066767578125}, {"value": "3", "count": 4649, "ratio": 0.045400390625}, {"value": "5", "count": 4151, "ratio": 0.040537109375}, {"value...
# 7   [{"value": "0", "count": 4073, "ratio": 0.039775390625}, {"value": "4", "count": 3870, "ratio": 0.03779296875}, {"value": "3", "count": 3711, "ratio": 0.036240234375}, {"value"...
# 8   [{"value": "0", "count": 3293, "ratio": 0.032158203125}, {"value": "4", "count": 3028, "ratio": 0.0295703125}, {"value": "6", "count": 2978, "ratio": 0.02908203125}, {"value": ...
# 9   [{"value": "4", "count": 5115, "ratio": 0.049951171875}, {"value": "5", "count": 5010, "ratio": 0.04892578125}, {"value": "3", "count": 4644, "ratio": 0.0453515625}, {"value": ...
# 10  [{"value": "5", "count": 5692, "ratio": 0.0555859375}, {"value": "4", "count": 4669, "ratio": 0.045595703125}, {"value": "0", "count": 4192, "ratio": 0.0409375}, {"value": "3",...
# 11  [{"value": "4", "count": 4729, "ratio": 0.046181640625}, {"value": "5", "count": 3572, "ratio": 0.0348828125}, {"value": "6", "count": 3421, "ratio": 0.033408203125}, {"value":...
# 12  [{"value": "2", "count": 8674, "ratio": 0.08470703125}, {"value": "3", "count": 6144, "ratio": 0.06}, {"value": "4", "count": 4919, "ratio": 0.048037109375}, {"value": "1", "co...
# 13  [{"value": "2", "count": 8032, "ratio": 0.0784375}, {"value": "1", "count": 6132, "ratio": 0.0598828125}, {"value": "3", "count": 5854, "ratio": 0.05716796875}, {"value": "4", ...
# 14  [{"value": "2", "count": 8498, "ratio": 0.08298828125}, {"value": "3", "count": 6401, "ratio": 0.062509765625}, {"value": "4", "count": 6172, "ratio": 0.0602734375}, {"value": ...
# 15  [{"value": "1", "count": 11851, "ratio": 0.115732421875}, {"value": "2", "count": 7196, "ratio": 0.0702734375}, {"value": "4", "count": 4003, "ratio": 0.039091796875}, {"value"...
# 16  [{"value": "1", "count": 11290, "ratio": 0.11025390625}, {"value": "2", "count": 6194, "ratio": 0.06048828125}, {"value": "3", "count": 5450, "ratio": 0.05322265625}, {"value":...
# 17  [{"value": "1", "count": 12676, "ratio": 0.1237890625}, {"value": "2", "count": 10290, "ratio": 0.10048828125}, {"value": "3", "count": 6228, "ratio": 0.0608203125}, {"value": ...
# 18  [{"value": "4", "count": 6649, "ratio": 0.064931640625}, {"value": "6", "count": 5980, "ratio": 0.0583984375}, {"value": "3", "count": 5532, "ratio": 0.0540234375}, {"value": "...
# 19  [{"value": "4", "count": 6708, "ratio": 0.0655078125}, {"value": "5", "count": 6008, "ratio": 0.058671875}, {"value": "6", "count": 5151, "ratio": 0.050302734375}, {"value": "0...
# 20  [{"value": "3", "count": 5658, "ratio": 0.05525390625}, {"value": "4", "count": 4737, "ratio": 0.046259765625}, {"value": "2", "count": 4153, "ratio": 0.040556640625}, {"value"...
# 21  [{"value": "5", "count": 7529, "ratio": 0.073525390625}, {"value": "8", "count": 7222, "ratio": 0.07052734375}, {"value": "7", "count": 5572, "ratio": 0.0544140625}, {"value": ...
# 22  [{"value": "6", "count": 7455, "ratio": 0.072802734375}, {"value": "5", "count": 7435, "ratio": 0.072607421875}, {"value": "8", "count": 5548, "ratio": 0.0541796875}, {"value":...
# 23  [{"value": "6", "count": 6293, "ratio": 0.061455078125}, {"value": "4", "count": 6081, "ratio": 0.059384765625}, {"value": "7", "count": 5530, "ratio": 0.05400390625}, {"value"...
# 24  [{"value": "2", "count": 6832, "ratio": 0.06671875}, {"value": "3", "count": 6125, "ratio": 0.059814453125}, {"value": "4", "count": 5410, "ratio": 0.05283203125}, {"value": "5...
# 25  [{"value": "2", "count": 8606, "ratio": 0.08404296875}, {"value": "3", "count": 7220, "ratio": 0.0705078125}, {"value": "4", "count": 6300, "ratio": 0.0615234375}, {"value": "5...
# 26  [{"value": "3", "count": 7136, "ratio": 0.0696875}, {"value": "1", "count": 6459, "ratio": 0.063076171875}, {"value": "2", "count": 6214, "ratio": 0.06068359375}, {"value": "4"...
# 27  [{"value": "4", "count": 6557, "ratio": 0.064033203125}, {"value": "3", "count": 6372, "ratio": 0.0622265625}, {"value": "5", "count": 6113, "ratio": 0.059697265625}, {"value":...
# 28  [{"value": "3", "count": 10038, "ratio": 0.09802734375}, {"value": "4", "count": 6926, "ratio": 0.06763671875}, {"value": "2", "count": 5952, "ratio": 0.058125}, {"value": "5",...
# 29  [{"value": "2", "count": 7575, "ratio": 0.073974609375}, {"value": "3", "count": 6235, "ratio": 0.060888671875}, {"value": "5", "count": 5671, "ratio": 0.055380859375}, {"value...
#
#    selected_decode_method  selected_foreground_ratio  \
# 0         range_clean_pm2                   0.360713
# 1         range_clean_pm2                   0.387725
# 2         range_clean_pm2                   0.304004
# 3    multiotsu_non_border                   0.429863
# 4    multiotsu_non_border                   0.409561
# 5         range_clean_pm2                   0.421504
# 6         range_clean_pm2                   0.359258
# 7         range_clean_pm2                   0.344414
# 8         range_clean_pm2                   0.300537
# 9    multiotsu_non_border                   0.433174
# 10        range_clean_pm2                   0.414229
# 11        range_clean_pm2                   0.416025
# 12        range_clean_pm2                   0.435977
# 13        range_clean_pm2                   0.482354
# 14   multiotsu_non_border                   0.356113
# 15        range_clean_pm2                   0.620361
# 16   multiotsu_non_border                   0.341230
# 17   multiotsu_non_border                   0.421973
# 18        range_clean_pm2                   0.455322
# 19        range_clean_pm2                   0.472871
# 20        range_clean_pm2                   0.420391
# 21        range_clean_pm2                   0.592266
# 22        range_clean_pm2                   0.543389
# 23        range_clean_pm2                   0.491670
# 24        range_clean_pm2                   0.416104
# 25        range_clean_pm2                   0.418164
# 26        range_clean_pm2                   0.412422
# 27        range_clean_pm2                   0.498857
# 28   multiotsu_non_border                   0.436211
# 29        range_clean_pm2                   0.490586
#
#     selected_component_count  \
# 0                          3
# 1                         10
# 2                          4
# 3                          2
# 4                          2
# 5                         11
# 6                          2
# 7                          3
# 8                          3
# 9                          3
# 10                         8
# 11                         8
# 12                         1
# 13                         2
# 14                         2
# 15                         2
# 16                         2
# 17                         2
# 18                         4
# 19                         2
# 20                         4
# 21                        12
# 22                         9
# 23                        10
# 24                         2
# 25                         2
# 26                         2
# 27                         8
# 28                         3
# 29                         5
#
#                                                                                                                                                                             decode_info  \
# 0   {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [9, 8, 10, 11, 6, 12, 7, 13], "unique_count": 252, "border_bg": 0, "foreground_ra...
# 1   {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [8, 5, 6, 7, 9, 11, 10, 4], "unique_count": 249, "border_bg": 0, "foreground_rati...
# 2   {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [4, 5, 6, 7, 8, 9, 3, 11], "unique_count": 244, "border_bg": 0, "foreground_ratio...
# 3   {"selected_method": "multiotsu_non_border", "score": 4, "method": "multiotsu_non_border", "thresholds": [31.376953125, 74.208984375, 131.982421875, 188.759765625], "border_clas...
# 4   {"selected_method": "multiotsu_non_border", "score": 4, "method": "multiotsu_non_border", "thresholds": [25.400390625, 58.271484375, 102.099609375, 160.869140625], "border_clas...
# 5   {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [7, 6, 9, 10, 8, 11, 4, 5], "unique_count": 252, "border_bg": 0, "foreground_rati...
# 6   {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [4, 3, 5, 6, 2, 1, 7, 9], "unique_count": 253, "border_bg": 0, "foreground_ratio"...
# 7   {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [4, 3, 6, 5, 2, 7, 11, 8], "unique_count": 251, "border_bg": 0, "foreground_ratio...
# 8   {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [4, 6, 3, 5, 9, 7, 1, 2], "unique_count": 253, "border_bg": 0, "foreground_ratio"...
# 9   {"selected_method": "multiotsu_non_border", "score": 4, "method": "multiotsu_non_border", "thresholds": [22.412109375, 59.267578125, 111.064453125, 161.865234375], "border_clas...
# 10  {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [5, 4, 3, 6, 7, 2, 8, 9], "unique_count": 247, "border_bg": 0, "foreground_ratio"...
# 11  {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [4, 5, 6, 3, 7, 11, 8, 9], "unique_count": 248, "border_bg": 0, "foreground_ratio...
# 12  {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [2, 3, 4, 1, 5, 6, 7, 8], "unique_count": 254, "border_bg": 0, "foreground_ratio"...
# 13  {"selected_method": "range_clean_pm2", "score": 2, "method": "range_clean_pm2", "used_values": [2, 1, 3, 4, 5, 6, 7, 8], "unique_count": 247, "border_bg": 0, "foreground_ratio"...
# 14  {"selected_method": "multiotsu_non_border", "score": 4, "method": "multiotsu_non_border", "thresholds": [24.404296875, 63.251953125, 126.005859375, 186.767578125], "border_clas...
# 15  {"selected_method": "range_clean_pm2", "score": 2, "method": "range_clean_pm2", "used_values": [1, 2, 4, 6, 7, 9, 3, 10], "unique_count": 243, "border_bg": 0, "foreground_ratio...
# 16  {"selected_method": "multiotsu_non_border", "score": 4, "method": "multiotsu_non_border", "thresholds": [25.400390625, 74.208984375, 129.990234375, 174.814453125], "border_clas...
# 17  {"selected_method": "multiotsu_non_border", "score": 4, "method": "multiotsu_non_border", "thresholds": [14.443359375, 49.306640625, 114.052734375, 175.810546875], "border_clas...
# 18  {"selected_method": "range_clean_pm2", "score": 2, "method": "range_clean_pm2", "used_values": [4, 6, 3, 7, 5, 8, 9, 10], "unique_count": 250, "border_bg": 0, "foreground_ratio...
# 19  {"selected_method": "range_clean_pm2", "score": 2, "method": "range_clean_pm2", "used_values": [4, 5, 6, 7, 3, 8, 2, 10], "unique_count": 250, "border_bg": 0, "foreground_ratio...
# 20  {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [3, 4, 2, 5, 6, 7, 9, 8], "unique_count": 244, "border_bg": 0, "foreground_ratio"...
# 21  {"selected_method": "range_clean_pm2", "score": 2, "method": "range_clean_pm2", "used_values": [5, 8, 7, 6, 10, 9, 4, 13], "unique_count": 255, "border_bg": 0, "foreground_rati...
# 22  {"selected_method": "range_clean_pm2", "score": 2, "method": "range_clean_pm2", "used_values": [6, 5, 8, 7, 4, 10, 3, 11], "unique_count": 246, "border_bg": 0, "foreground_rati...
# 23  {"selected_method": "range_clean_pm2", "score": 2, "method": "range_clean_pm2", "used_values": [6, 4, 7, 8, 5, 3, 10, 11], "unique_count": 241, "border_bg": 0, "foreground_rati...
# 24  {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [2, 3, 4, 5, 6, 1, 7, 8], "unique_count": 256, "border_bg": 0, "foreground_ratio"...
# 25  {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [2, 3, 4, 5, 1, 6, 8, 7], "unique_count": 256, "border_bg": 0, "foreground_ratio"...
# 26  {"selected_method": "range_clean_pm2", "score": 4, "method": "range_clean_pm2", "used_values": [3, 1, 2, 4, 5, 7, 6, 9], "unique_count": 243, "border_bg": 0, "foreground_ratio"...
# 27  {"selected_method": "range_clean_pm2", "score": 2, "method": "range_clean_pm2", "used_values": [4, 3, 5, 2, 7, 6, 8, 9], "unique_count": 245, "border_bg": 0, "foreground_ratio"...
# 28  {"selected_method": "multiotsu_non_border", "score": 4, "method": "multiotsu_non_border", "thresholds": [21.416015625, 59.267578125, 111.064453125, 161.865234375], "border_clas...
# 29  {"selected_method": "range_clean_pm2", "score": 2, "method": "range_clean_pm2", "used_values": [2, 3, 5, 4, 1, 6, 8, 7], "unique_count": 251, "border_bg": 0, "foreground_ratio"...
#
#    auto_status manual_accept manual_reject_reason notes
# 0       review
# 1       review
# 2       review
# 3       review
# 4       review
# 5       review
# 6       review
# 7       review
# 8       review
# 9       review
# 10      review
# 11      review
# 12      review
# 13      review
# 14      review
# 15      review
# 16      review
# 17      review
# 18      review
# 19      review
# 20      review
# 21      review
# 22      review
# 23      review
# 24      review
# 25      review
# 26      review
# 27      review
# 28      review
# 29      review
#         gt_type modality selected_decode_method   n
# 1  intermediary       T1        range_clean_pm2  59
# 3  intermediary       T2        range_clean_pm2  43
# 2  intermediary       T2   multiotsu_non_border  17
# 0  intermediary       T1   multiotsu_non_border   1

# %%
# 4) Reporte final FIXED
report = {
    'notebook': '16_E8_alkafri_mask_decode_FIXED',
    'goal': 'compare final/intermediary/manual GT source and improve mask decoding visual diagnostics',
    'input_official_candidates': str(OFFICIAL_FILTERED_PATH),
    'official_candidates_loaded': int(len(official_df)),
    'gt_png_parsed': int(len(gt_df)),
    'selected_candidates_best_gt_source': int(len(selected_df)),
    'selected_by_gt_type_modality': selected_df.groupby(['gt_type', 'modality'], dropna=False).size().reset_index(name='n').to_dict(orient='records'),
    'visual_review_figures': int(review_fixed_df.get('figure_path', pd.Series(dtype=object)).notna().sum()),
    'review_sheet': str(E8_ROOT / 'E8_FIXED_mask_decode_visual_review_sheet.csv'),
    'figures_prefix': str(FIGURES_ROOT / 'E8_alkafri_FIXED_MASK_DECODE_###.png'),
    'decision': 'pending_visual_review',
    'recommendation': 'Abrir figuras FIXED. Si las máscaras limpias caen sobre regiones anatómicas coherentes en al menos 30 casos, crear subset axial curado. Si siguen siendo ruido/dispersión, el pairing está resuelto pero la decodificación de GT no es entrenable todavía.'
}

report_path = E8_ROOT / 'E8_FIXED_mask_decode_report.json'
report_path.write_text(json.dumps(report, indent=2, ensure_ascii=False), encoding='utf-8')

md = [
    '# E8 FIXED mask decode conclusion',
    '',
    f'- Official candidates loaded: {len(official_df)}',
    f'- Parsed GT PNG files: {len(gt_df)}',
    f'- Selected candidates with best GT source: {len(selected_df)}',
    f'- Fixed visual review figures: {report["visual_review_figures"]}',
    '',
    '## Interpretation',
    'The official pairing stage is considered recovered. This notebook evaluates whether the available GT sources can be decoded into trainable anatomical masks.',
    '',
    '## Next decision',
    report['recommendation'],
]
(DOCS_ROOT / 'E8_FIXED_mask_decode_conclusion.md').write_text('\n'.join(md), encoding='utf-8')

print(json.dumps(report, indent=2, ensure_ascii=False))
print('Reporte:', report_path)
# Out:
# {
#   "notebook": "16_E8_alkafri_mask_decode_FIXED",
#   "goal": "compare final/intermediary/manual GT source and improve mask decoding visual diagnostics",
#   "input_official_candidates": "/content/drive/MyDrive/PFI_MVP/results/E8_alkafri_official_pairing/E8_official_pairing_candidates_HEADER_NONE_FILTERED.csv",
#   "official_candidates_loaded": 1201,
#   "gt_png_parsed": 18540,
#   "selected_candidates_best_gt_source": 1201,
#   "selected_by_gt_type_modality": [
#     {
#       "gt_type": "intermediary",
#       "modality": "T1",
#       "n": 591
#     },
#     {
#       "gt_type": "intermediary",
#       "modality": "T2",
#       "n": 610
#     }
#   ],
#   "visual_review_figures": 120,
#   "review_sheet": "/content/drive/MyDrive/PFI_MVP/results/E8_alkafri_official_pairing/E8_FIXED_mask_decode_visual_review_sheet.csv",
#   "figures_prefix": "/content/drive/MyDrive/PFI_MVP/figures/E8_alkafri_FIXED_MASK_DECODE_###.png",
#   "decision": "pending_visual_review",
#   "recommendation": "Abrir figuras FIXED. Si las máscaras limpias caen sobre regiones anatómicas coherentes en al menos 30 casos, crear subset axial curado. Si siguen siendo ruido/dispersión, el pairing está resuelto pero la decodificación de GT no es entrenable todavía."
# }
# Reporte: /content/drive/MyDrive/PFI_MVP/results/E8_alkafri_official_pairing/E8_FIXED_mask_decode_report.json

# %%
# DIAGNÓSTICO: buscar ground truth FINAL que no se está parseando

raw_gt_index = pd.read_csv(GT_INDEX_PATH, low_memory=False)

raw_gt_index["path_lower"] = raw_gt_index["gt_file_path"].astype(str).str.lower()
raw_gt_index["name"] = raw_gt_index["gt_file_path"].apply(lambda x: Path(str(x)).name)
raw_gt_index["parent"] = raw_gt_index["gt_file_path"].apply(lambda x: str(Path(str(x)).parent))

final_like = raw_gt_index[
    raw_gt_index["extension"].astype(str).str.lower().eq(".png")
    & (
        raw_gt_index["path_lower"].str.contains("05_final", na=False)
        | raw_gt_index["path_lower"].str.contains("final_ground_truth", na=False)
        | raw_gt_index["path_lower"].str.contains("final", na=False)
    )
].copy()

print("raw_gt_index:", raw_gt_index.shape)
print("final_like PNG:", final_like.shape)

display(
    final_like[[
        "gt_file_path",
        "gt_relative_path",
        "case_id",
        "modality",
        "disc_or_slice_id",
        "gt_type",
        "extension",
        "name",
        "parent",
    ]].head(80)
)

display(
    final_like["parent"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "parent", "parent": "n"})
    .head(30)
)

display(
    final_like["name"]
    .head(100)
    .to_frame()
)

# Ver qué nombres tienen los archivos finales
if len(final_like) > 0:
    final_like["parsed_by_old_regex"] = final_like["name"].str.extract(
        r"(T[12])[_-](\d{1,4})[_-]D([345])",
        expand=False
    ).notna().all(axis=1)

    print("Parseables con regex viejo:")
    print(final_like["parsed_by_old_regex"].value_counts(dropna=False))

    display(
        final_like[~final_like["parsed_by_old_regex"]][
            ["gt_file_path", "name", "parent"]
        ].head(100)
    )
# Out:
# raw_gt_index: (37080, 11)
# final_like PNG: (6180, 11)
#                                                                                                                                                           gt_file_path  \
# 23175  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0001_D3.png
# 23176  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0001_D4.png
# 23177  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0001_D5.png
# 23178  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0002_D3.png
# 23179  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0002_D4.png
# ...                                                                                                                                                                ...
# 23250  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0027_D3.png
# 23251  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0027_D4.png
# 23252  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0027_D5.png
# 23253  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0029_D3.png
# 23254  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0029_D4.png
#
#                                                                                           gt_relative_path  \
# 23175  _nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0001_D3.png
# 23176  _nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0001_D4.png
# 23177  _nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0001_D5.png
# 23178  _nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0002_D3.png
# 23179  _nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0002_D4.png
# ...                                                                                                    ...
# 23250  _nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0027_D3.png
# 23251  _nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0027_D4.png
# 23252  _nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0027_D5.png
# 23253  _nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0029_D3.png
# 23254  _nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0029_D4.png
#
#        case_id modality  disc_or_slice_id gt_type extension            name  \
# 23175        1      NaN                 3   final      .png  C1_0001_D3.png
# 23176        1      NaN                 4   final      .png  C1_0001_D4.png
# 23177        1      NaN                 5   final      .png  C1_0001_D5.png
# 23178        2      NaN                 3   final      .png  C1_0002_D3.png
# 23179        2      NaN                 4   final      .png  C1_0002_D4.png
# ...        ...      ...               ...     ...       ...             ...
# 23250       27      NaN                 3   final      .png  C1_0027_D3.png
# 23251       27      NaN                 4   final      .png  C1_0027_D4.png
# 23252       27      NaN                 5   final      .png  C1_0027_D5.png
# 23253       29      NaN                 3   final      .png  C1_0029_D3.png
# 23254       29      NaN                 4   final      .png  C1_0029_D4.png
#
#                                                                                                                                                  parent
# 23175  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23176  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23177  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23178  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23179  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# ...                                                                                                                                                 ...
# 23250  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23251  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23252  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23253  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23254  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
#
# [80 rows x 9 columns]
#                                                                                                                                                           n  \
# 0          /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 1              /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Label_Images
# 2  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Resized_Composite_Images
# 3      /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Resized_Label_Images
#
#    count
# 0   1545
# 1   1545
# 2   1545
# 3   1545
#                  name
# 23175  C1_0001_D3.png
# 23176  C1_0001_D4.png
# 23177  C1_0001_D5.png
# 23178  C1_0002_D3.png
# 23179  C1_0002_D4.png
# ...               ...
# 23270  C1_0034_D5.png
# 23271  C1_0035_D3.png
# 23272  C1_0035_D4.png
# 23273  C1_0035_D5.png
# 23274  C1_0036_D3.png
#
# [100 rows x 1 columns]
# Parseables con regex viejo:
# parsed_by_old_regex
# False    6180
# Name: count, dtype: int64
#                                                                                                                                                           gt_file_path  \
# 23175  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0001_D3.png
# 23176  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0001_D4.png
# 23177  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0001_D5.png
# 23178  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0002_D3.png
# 23179  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0002_D4.png
# ...                                                                                                                                                                ...
# 23270  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0034_D5.png
# 23271  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0035_D3.png
# 23272  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0035_D4.png
# 23273  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0035_D5.png
# 23274  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images/C1_0036_D3.png
#
#                  name  \
# 23175  C1_0001_D3.png
# 23176  C1_0001_D4.png
# 23177  C1_0001_D5.png
# 23178  C1_0002_D3.png
# 23179  C1_0002_D4.png
# ...               ...
# 23270  C1_0034_D5.png
# 23271  C1_0035_D3.png
# 23272  C1_0035_D4.png
# 23273  C1_0035_D5.png
# 23274  C1_0036_D3.png
#
#                                                                                                                                                  parent
# 23175  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23176  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23177  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23178  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23179  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# ...                                                                                                                                                 ...
# 23270  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23271  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23272  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23273  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
# 23274  /content/drive/MyDrive/PFI_MVP/data/AXIAL_ALKAFRI/extracted/_nested/ground_truth__Ground_Truth_Label/05_Final_Ground_Truth_Data/Composite_Images
#
# [100 rows x 3 columns]
